# %% [markdown]
# <a href="https://colab.research.google.com/github/rockfiller/News_Key_Word_Analysis/blob/main/News_Key_Word_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安裝 jieba 中文斷詞套件
# !pip install jieba

# 下載官方字典檔
# !wget https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big


# 載入套件與字典檔
import jieba
jieba.load_userdict("dict.txt.big")
import requests
from bs4 import BeautifulSoup

# Use requests to send a request to the API.
response = requests.get('https://udn.com/news/breaknews/1')
soup = BeautifulSoup(response.text)

news = []
for link in soup.find_all('h3', class_='rounded-thumb__title')[:4]:
  news_url = link.a['href']
  news_response = requests.get('https://udn.com' + news_url)
  news_soup = BeautifulSoup(news_response.text)
  news_content = news_soup.find('div', class_='article-content__paragraph').text.strip().replace('\n', ' ')
  news.append(news_content)
print(news)

# 精確模式斷詞
tokens = []
for d in news:
  token = list(jieba.cut(d, HMM=False)) # token = d 字串斷詞結果
  tokens.append(token)
print(tokens)

word_count = {}
for t in tokens:
    for w in t:
        if w not in word_count:
            word_count[w] = 0
        word_count[w] += 1

word_count = dict(sorted(word_count.items(), reverse=True, key=lambda item: item[1]))
print(word_count)
# {'聲明': 4, '主管機關': 3, ...}
# Out:
# Requirement already satisfied: jieba in /usr/local/lib/python3.10/dist-packages (0.42.1)
# --2024-07-18 06:36:29--  https://raw.githubusercontent.com/fxsjy/jieba/master/extra_dict/dict.txt.big
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 8583143 (8.2M) [application/octet-stream]
# Saving to: ‘dict.txt.big.15’
#
# dict.txt.big.15     100%[===================>]   8.18M  --.-KB/s    in 0.1s
#
# 2024-07-18 06:36:29 (81.1 MB/s) - ‘dict.txt.big.15’ saved [8583143/8583143]
#
# ['「可不可熟成紅茶」新竹關埔分店范姓女店員，因不滿客人快打烊時點餐，竟在手上吐口水，再徒手攪拌白玉珍珠。「加料口水手搖飲」畫面曝光後，引起網友一片撻伐，可不可總公司除終止加盟合作關係外，據傳擬向范女求償450萬的商譽損失，因不堪外界輿論，今天總公司「玩真的」，直接找來外包商拆除關埔店招牌，確定不再營業。 \r 「可不可熟成紅茶」新竹關埔店，14日范姓女店員因不滿顧客在打烊前壓線點單，便故意在手上吐口水後再攪拌白玉珍珠，另一人則全程錄影PO網，還嗆聲「打烊前訂的都去死」，影片立刻引發眾怒。            \r 事件爆發後，發文者雖然很快撤下影片，仍止不住網友撻伐，至15日下午疑似片中惡作劇的女店員發文道歉，表示因一時「好玩」引起騷動，已深刻反省並向老闆自請離職，不過不久後又在限時動態抱怨：「已經道歉了，你們還想怎樣，該賠的我會賠」，囂張的態度再度引來網友炎上。 \r 不過道歉文無法止血，可不可總公司隨即發表「終止加盟合作關係」，該店即起停業並永久終止與該加盟主的合作關係，並追究所有法律責任。由於輿論不斷延燒，已停業2天的新竹關埔店，今天上午多名工程人員前往招牌拆除，確定不再營業，盼能止血。 \r 可不可總公司也表示，已由總部營運督導聯繫上當事消費者，除協助訂單款項退費外，也會持續追蹤訂購者身心狀態，後續待事主時間許可，會再主動進行關懷及拜訪。可不可新竹關埔分店范姓女員工因「加料口水手搖飲」遭網友撻伐，今天總公司「玩真的」，直接找來外包商拆除關埔店招牌，確定不再營業。圖／民眾提供     可不可熟成紅茶 新竹', '前
# [['「', '可', '不可', '熟', '成', '紅茶', '」', '新竹', '關', '埔', '分店', '范', '姓', '女店員', '，', '因', '不滿', '客人', '快', '打烊', '時點', '餐', '，', '竟', '在', '手上', '吐口', '水', '，', '再', '徒手', '攪拌', '白玉', '珍珠', '。', '「', '加料', '口水', '手搖', '飲', '」', '畫面', '曝光', '後', '，', '引起', '網友', '一片', '撻伐', '，', '可', '不可', '總公司', '除', '終止', '加盟', '合作', '關係', '外', '，', '據傳', '擬向', '范', '女', '求償', '450', '萬', '的', '商譽', '損失', '，', '因', '不堪', '外界', '輿論', '，', '今天', '總公司', '「', '玩', '真的', '」', '，', '直接', '找來', '外', '包商', '拆除', '關', '埔', '店', '招牌', '，', '確定', '不再', '營業', '。', ' ', '\r', ' ', '「', '可', '不可', '熟', '成', '紅茶', '」', '新竹', '關', '埔', '店', '，', '14', '日', '范', '姓', '女店員', '因', '不滿', '顧客', '在', '打烊', '前', '壓線', '點', '單', '，', '便', '故意', '在', '手上', '吐口', '水', '後', '再', '攪拌', '白玉', '珍珠', '，', '另一人', '則', '全程', '錄影', 'PO', '網', '，', '還', '嗆', '聲', '「', '打烊', '前', '訂', '的', '都', '去', '死', '」', '，', '影片', '立刻', '引發', '眾', '怒', '。', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '\r', ' ', '事件', '爆發', '後', '，', '發文者', '雖然', '很快', '撤下', '影片', '，', '仍', '止不住', '網友', '撻伐', '，', '至', '15', '日', '下午', '疑似', '片中', '惡作劇', '的', '女店員', '發文', '道歉', '，', '表示', '因', '一時', '「', '好玩', '」', '引起', '騷動', '，', '已', '深刻', '反省', '並', '向', '老闆', '自', '請', '離職', '，', '不過', '不久', '後', '又', '在', '限時', '動態', '抱怨', '：', '「', '已經', '道歉', '了', '，', '你們', '還', '想', '怎樣', '，', '該', '賠', '的', '我會', '賠', '」', '，', '囂張', '的', '態度', '再度', '引來', '網友', '炎', '上', '。', ' ', '\r', ' ', '不過', '道歉', '文', '無法', '止血', '，', '可', '不可', '總公司', '隨即', '發表', '「', '終止', '加盟', '合作', '關係', '」', '，', '該店', '即', '起', '停業', '並', '永久', '終止', '與', '該', '加盟', '主', '的', '合作', '關係', '，', '並', '追究', '所有', '法律責任', '。', '由於', '輿論', '不斷', '延燒', '，', '已', '停業', '2', '天', '的', '新竹', '關', '埔', '店', '，', '今天上午', '多名', '工程', '人員', '前往', '招牌', '拆除', '，', '確定', '不再', '營業', '，', '盼', '能', '止血', '。', ' ', '\r', ' ', '可', '不可', '總公司', '也', '表示', '，', '已', '由', '總部', '營運', '督導', '聯繫', '上當', '事', '消費者', '，', '除', '協助', '訂單', '款項', '退費', '外', '，', '也', '會', '持續', '追蹤', '訂購者', '身心狀態', '，', '後續', '待', '事主', '時間', '許可', '，', '會', '再', '主動', '進行', '關懷', '及', '拜訪', '。', '可', '不可', '新竹', '關', '埔', '分店', '范', '姓', '女', '員工', '因', '「', '加料', '口水', '手搖', '飲', '」', '遭', '網友', '撻伐', '，', '今天', '總公司', '「', '玩', '真的', '」', '，', '直接', '找來', '外', '包商', '拆除', '關', '埔', '店', '招牌', '，', '確定', '不再', '營業', '。', '圖', '／', '民', '眾', '提供', ' ', ' ', ' ', ' ', ' ', '可', '不可', '熟', '成', '紅茶', ' ', '新竹'], ['前', '美國', '總統', '川', '普', '稱', '台', '灣', '搶走', '晶片', '生意', '，', '應向', '美國', '付', '保護費', '，', '對此', '，', '國科會', '主委', '吳', '誠', '文', '17', '日', '在', '國科會', '委員會', '會後', '記者會', '上', '表示', '，', '台', '灣', '科技', '實力', '已', '與', '美', '、', '日', '、', '歐盟', '等', '形成', '良好', '國際', '夥伴關係', '，', '不會', '輕易', '被', '破壞', '掉', '。', ' ', '\r', ' ', '川', '普', '發言', '，', '震驚', '海內外', '。', '吳', '誠', '文', '表示', '，', '台', '灣', '要', '謹慎', '應對', '，', '國際', '政治', '及', '地緣', '政治', '都', '會', '對', '我國', '產業', '有所', '影響', '。', '他', '認', '為', '，', '現在', '美國', '總統', '競選', '期間', '，', '很多', '政治', '語言', '，', '最後', '也', '不', '一定', '會', '成', '為', '事實', '。', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', ' ', '\r', ' ', '他', '相信', '，', '台', '灣', '只要', '堅守', '民主自由', '社會', '的', '價值', '，', '台', '灣', '就', '不', '孤單', '，', '也', '不是', '一個', '人', '的', '意見', '就', '可以', '將', '台', '灣', '摒除', '在', '民主自由', '陣營', '。', '他', '並說', '，', '台', '灣', '科技', '實力', '已', '形成', '良好', '國際', '夥伴關係', '，', '美國', '、', '日本', '、', '歐盟', '等', '皆', '是', '如此', '，', '不會', '輕易', '被', '破壞', '掉', '。', '🏠', 'udn', '房地產', '-', '推薦', '新聞', ' ', ' ', '▪', ' ', '買', '桃園', '房', '搭', '捷運', '通勤', '台北', '很', '愚蠢', '？', ' ', '過來人', '曝', '2', '缺點', '：', '真的', '麻煩', ' ', ' ', '▪', ' ', '亞', '昕', '16', '.', '9', '億元', '買', '台中', '5', '千', '坪', '土地', ' ', '今年以來', '豪', '砸', '96', '億元', '狂', '買', '地', ' ', ' ', '▪', ' ', '機械式', '危險', '又', '難', '脫手', '？', '他', '遇', '滿意', '建', '案', '卻', '因', '車位', '猶豫', ' ', '過來人', '：', '絕對', '比', '沒有', '好', ' ', ' ', '▪', ' ', '營建', '類', '股', '指數', '創', '歷史', '新高', ' ', '專家', '：', '民', '眾', '盼', '嘸', ' ...
# {' ': 116, '，': 97, '。': 28, '「': 15, '」': 15, '家屬': 14, '的': 13, '\r': 11, '、': 10, '病患': 10, '可': 9, '在': 9, '護理': 9, '師': 9, '不可': 7, '姓': 7, '已': 7, '台': 7, '灣': 7, '他': 7, '關': 6, '埔': 6, '因': 6, '？': 6, '賴': 6, '男': 6, '新竹': 5, '後': 5, '總公司': 5, '眾': 5, '表示': 5, '並': 5, '文': 5, '會': 5, '美國': 5, '不': 5, '▪': 5, '有': 5, '名譽': 5, '警方': 
': 1, '疑似': 1, '片中': 1, '惡作劇': 1, '發文': 1, '一時': 1, '好玩': 1, '騷動': 1, '深刻': 1, '反省': 1, '老闆': 1, '自': 1, '離職': 1, '不久': 1, '限時': 1, '動態': 1, '抱怨': 1, '已經': 1, '了': 1, '怎樣': 1, '我會': 1, '囂張': 1, '態度': 1, '再度': 1, '引來': 1, '炎': 1, '隨即': 1, '發表': 1, '該店': 1, '即': 1, '起': 1, '永久': 1, '主': 1, '追究': 1, '所有': 1, '法律責任': 1, '由於': 1, '延燒': 1, '天': 1, '多名': 1, '工程': 1, '人員': 1, '前往': 1, '能': 1, '由': 1, '總部': 1, '營運': 1, '督導': 1, '聯繫': 1, '上當': 1, '事': 1, '消費者': 1, '協助': 1, '訂單': 1, '款項': 1, '退費': 1, '持續': 1, '追蹤': 1, '訂購者': 1, '身心狀態': 1, '待': 1, '事主': 1, '時間': 1, '許可': 1, '主動': 1, '進行': 1, '關懷': 1, '拜訪': 1, '員工': 1, '稱': 1, '搶走': 1, '晶片': 1, '生意': 1, '應向': 1, '付': 1, '保護費': 1, '主委': 1, '17': 1, '委員會': 1, '會後': 1, '記者會': 1, '美': 1, '發言': 1, '震驚': 1, '海內外': 1, '謹慎': 1, '應對': 1, '地緣': 1, '我國': 1, '產業': 1, '有所': 1, '影響': 1, '認': 1, '現在': 1, '競選': 1, '期間': 1, '語言': 1, '最後': 1, '事實': 1, '相信': 1, '只要': 1, '堅守': 1, '社會': 1, '價值': 1, '孤單': 1, '人': 1, '意見': 1, '可以': 1, '將': 1, '摒除': 1, '陣營': 1, '並說': 1, '日本': 1, '皆': 1, '是': 1, '如此': 1, '🏠': 1, 'udn': 1, '房地產': 1, '-': 1, '推薦': 1, '新聞': 1, '桃園': 1, '搭': 1, '捷運': 1, '通勤': 1, '台北': 1, '很': 1, '愚蠢': 1, '曝': 1, '缺點': 1, '麻煩': 1, '亞': 1, '昕': 1, '16': 1, '9': 1, '台中': 1, '5': 1, '千': 1, '坪': 1, '土地': 1, '今年以來': 1, '豪': 1, '砸': 1, '96': 1, '狂': 1, '地': 1, '機械式': 1, '危險': 1, '難': 1, '脫手': 1, '遇': 1, '滿意': 1, '案': 1, '車位': 1, '猶豫': 1, '絕對': 1, '比': 1, '好': 1, '營建': 1, '類': 1, '股': 1, '指數': 1, '創': 1, '歷史': 1, '新高': 1, '專家': 1, '嘸': 1, '房價': 1, '降溫': 1, '打': 1, '贏': 1, '加入': 1, '房市': 1, '繼續': 1, '飛': 1, '一': 1, '表': 1, '透露': 1, '商': 1, '想像': 1, '信心': 1, '8': 1, '44': 1, '規模': 1, '不小': 1, '遠處': 1, '國道': 1, '看到': 1, '直': 1, '竄': 1, '天際': 1, '甚至': 1, '巨大': 1, '蕈': 1, '駭人': 1, '從': 1, '看出': 1, '發生': 1, '時候': 1, '出現': 1, '爆炸聲': 1, '猛烈': 1, '火': 1, '團': 1, '幾層樓': 1, '高': 1, '現場 ...
